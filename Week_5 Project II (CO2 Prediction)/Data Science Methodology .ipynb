# %% [markdown]
# https://www.amazon.com/Pampers-Sensitive-Water-Based-Pop-Top-Refill/dp/B07JRBSPZ3/ref=zg_bs_baby-products_1/144-3329381-7669825?pd_rd_i=B09ZLSSQR6&th=2

# %%
num_rows = 50
for i in range(num_rows+1):
    url = f'https://www.amazon.com/Pampers-Sensitive-Water-Based-Pop-Top-Refill/dp/B07JRBSPZ3/ref=zg_bs_baby-products_1/144-3329381-7669825?pd_rd_i=B09ZLSSQR6&th={i}'
    price =

# %% [markdown]
# #  Data Science Methodology

# %% [markdown]
# ###  Lesson Outline
#
#     1. Introduction to Data Science
#     2. Differences between Data Science and Data Analytics
#     3. Data Science Application
#     4. Data Science Methodology
#     5. Use Cases
#
# ### Next !

# %% [markdown]
# ### 1. Introduction to Data Science

# %% [markdown]
# ### What is Data Science?
#
# Data Science can be defined as a vast field of study, that makes use of various skills such as;
# * Mathematics
# * Business understanding
# * Domain understanding
# * Software engineering
# * Programming
# * Computer science
# * Statistics etc.
#
# to extract **actionable** insights from data (structured or unstructured) which can be used for decision making and profit maximization.

# %% [markdown]
# ### 2. Differences between Data Science and Data Analytics

# %% [markdown]
# **Data Analyst**
# - Visualization
# - Presentation
# - Data Wrangling etc.

# %% [markdown]
# **Data Scientist**
# - Data Wrangling
# - Data Modelling
# - Model Deployment and optimization etc

# %% [markdown]
# ### 3. Data Science Application

# %% [markdown]
# ![DSAPP.PNG](attachment:DSAPP.PNG)

# %% [markdown]
# ### 4. Data Science Methodology

# %% [markdown]
# ![METHod.PNG](attachment:METHod.PNG)

# %% [markdown]
# CRIPS-DM: Cross Industry Standard Process for Data Mining

# %% [markdown]
# ### 5. Use Cases

# %% [markdown]
# Kaggle: https://www.kaggle.com/competitions?hostSegmentIdFilter=5

# %% [markdown]
# # Next !
